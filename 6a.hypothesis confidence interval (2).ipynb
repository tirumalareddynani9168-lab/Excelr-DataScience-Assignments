# %%
# !pip install scipy

# %%
import math
from scipy.stats import norm

# %%
x_bar = 3050          
n = 25               
X_mean = 600          
sigma_X = 25          
alpha = 0.05

# %%
W_intercept = 1000
W_slope = 5
X_mean = 600

mu_model = W_intercept + W_slope * X_mean

H0_statement = f"The actual mean weekly cost is equal to or less)"
H1_statement = f"The actual mean weekly cost is greater)"

print(f"Calculated mu_model: {mu_model}")
print(f"Null Hypothesis (H0): {H0_statement}")
print(f"Alternative Hypothesis (H1): {H1_statement}")
# Out:
# Calculated mu_model: 4000
# Null Hypothesis (H0): The actual mean weekly cost is equal to or less)
# Alternative Hypothesis (H1): The actual mean weekly cost is greater)

# %%
import math

sigma = 125
n_sample = 25

standard_error = sigma / math.sqrt(n_sample)

print(f"Calculated Standard Error: {standard_error}")
# Out:
# Calculated Standard Error: 25.0

# %%
x_bar = 3050

Z_statistic = (x_bar - mu_model) / standard_error

print(f"Calculated Z-test statistic: {Z_statistic}")
# Out:
# Calculated Z-test statistic: -38.0

# %%
from scipy.stats import norm

alpha = 0.05

p_value = 1 - norm.cdf(Z_statistic)

print(f"Alpha level: {alpha}")
print(f"Calculated p-value: {p_value}")

# Compare p-value to alpha
print(f"Comparison: p-value ({p_value}) vs alpha ({alpha})")
# Out:
# Alpha level: 0.05
# Calculated p-value: 1.0
# Comparison: p-value (1.0) vs alpha (0.05)

# %%
# Standard Error
SE = sigma_W / math.sqrt(n)

# Z test statistic
z = (x_bar - mu_0) / SE

# Right-tailed p-value (H1: mu > mu0)
p_value = 1 - norm.cdf(z)

# Critical value for right-tailed test
z_critical = norm.ppf(1 - alpha)

# Decision
decision = "Reject H0" if z >= z_critical else "Fail to Reject"
# Print results
print("Theoretical mean (mu0):", mu_0)
print("Sigma_W:", sigma_W)
print("Standard Error (SE):", SE)
print("Z statistic:", z)
print("p-value (right-tailed):", p_value)
print("Critical z (alpha=0.05):", z_critical)
print("Decision:", decision)
# Out:
# Theoretical mean (mu0): 4000
# Sigma_W: 125
# Standard Error (SE): 25.0
# Z statistic: -38.0
# p-value (right-tailed): 1.0
# Critical z (alpha=0.05): 1.6448536269514722
# Decision: Fail to Reject
